# %% [markdown]
# # EDA for indian_railway dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#####Load DataSet

# %%
data = pd.read_csv('Copy of Indian_railway1.csv')

# %%
list(data.columns.values)  #### list of columns in the dataset
# Out:
# ['Train No',
#  'Train Name',
#  'SEQ',
#  'Station Code',
#  'Station Name',
#  'Arrival time',
#  'Departure Time',
#  'Distance',
#  'Source Station',
#  'Source Station Name',
#  'Destination Station',
#  'Destination Station Name']

# %%
data.dtypes   ######### datatype of the each column
# Out:
# Train No                     int64
# Train Name                  object
# SEQ                          int64
# Station Code                object
# Station Name                object
# Arrival time                object
# Departure Time              object
# Distance                     int64
# Source Station              object
# Source Station Name         object
# Destination Station         object
# Destination Station Name    object
# dtype: object

# %%
data["Departure Time"]=pd.to_timedelta(data['Departure Time'], unit='m') ### to convert object datatype to time

# %%
data["Arrival time"]=pd.to_timedelta(data['Arrival time'], unit='m') ### to convert object datatype to time

# %%
data.dtypes
# Out:
# Train No                              int64
# Train Name                           object
# SEQ                                   int64
# Station Code                         object
# Station Name                         object
# Arrival time                timedelta64[ns]
# Departure Time              timedelta64[ns]
# Distance                              int64
# Source Station                       object
# Source Station Name                  object
# Destination Station                  object
# Destination Station Name             object
# dtype: object

# %% [markdown]
# # EDA

# %%
data.shape
# Out:
# (186119, 12)

# %%
data.head()
# Out:
#    Train No    Train Name  SEQ Station Code  Station Name Arrival time  \
# 0       107  SWV-MAO-VLNK    1          SWV  SAWANTWADI R     00:00:00
# 1       107  SWV-MAO-VLNK    2         THVM        THIVIM     11:06:00
# 2       107  SWV-MAO-VLNK    3         KRMI       KARMALI     11:28:00
# 3       107  SWV-MAO-VLNK    4          MAO   MADGOAN JN.     12:10:00
# 4       108  VLNK-MAO-SWV    1          MAO   MADGOAN JN.     00:00:00
#
#   Departure Time  Distance Source Station Source Station Name  \
# 0       10:25:00         0            SWV     SAWANTWADI ROAD
# 1       11:08:00        32            SWV     SAWANTWADI ROAD
# 2       11:30:00        49            SWV     SAWANTWADI ROAD
# 3       00:00:00        78            SWV     SAWANTWADI ROAD
# 4       20:30:00         0            MAO         MADGOAN JN.
#
#   Destination Station Destination Station Name
# 0                 MAO              MADGOAN JN.
# 1                 MAO              MADGOAN JN.
# ...

# %%
data.tail()
# Out:
#         Train No Train Name  SEQ Station Code Station Name Arrival time  \
# 186114     99908        EMU    8         AKRD       AKURDI     23:30:00
# 186115     99908        EMU    9         DEHR    DEHU ROAD     23:35:00
# 186116     99908        EMU   10         BGWI    BEGDAEWAI     23:39:00
# 186117     99908        EMU   11         GRWD    GHORAWADI     23:41:00
# 186118     99908        EMU   12          TGN     TALEGAON     23:50:00
#
#        Departure Time  Distance Source Station Source Station Name  \
# 186114       23:31:00        19           PUNE            PUNE JN.
# 186115       23:36:00        24           PUNE            PUNE JN.
# 186116       23:40:00        28           PUNE            PUNE JN.
# 186117       23:42:00        31           PUNE            PUNE JN.
# 186118       00:00:00        34           PUNE            PUNE JN.
#
#        Destination Station Destination Station Name
# 186114                 TGN                 TALEGAON
# ...

# %%
data[data["Arrival time"].isnull()]  ### to find in which row there is a null value
# Out:
# Empty DataFrame
# Columns: [Train No, Train Name, SEQ, Station Code, Station Name, Arrival time, Departure Time, Distance, Source Station, Source Station Name, Destination Station, Destination Station Name]
# Index: []

# %%
data.shape
# Out:
# (186119, 12)

# %%
data.dtypes
# Out:
# Train No                              int64
# Train Name                           object
# SEQ                                   int64
# Station Code                         object
# Station Name                         object
# Arrival time                timedelta64[ns]
# Departure Time              timedelta64[ns]
# Distance                              int64
# Source Station                       object
# Source Station Name                  object
# Destination Station                  object
# Destination Station Name             object
# dtype: object

# %%
data['Arrival time']= pd.to_timedelta(data['Arrival time'],unit="s")   ####to covert object datatype to timedelta

# %%
data['Departure Time']= pd.to_timedelta(data['Departure Time'],unit="s")

# %%
data.dtypes
# Out:
# Train No                              int64
# Train Name                           object
# SEQ                                   int64
# Station Code                         object
# Station Name                         object
# Arrival time                timedelta64[ns]
# Departure Time              timedelta64[ns]
# Distance                              int64
# Source Station                       object
# Source Station Name                  object
# Destination Station                  object
# Destination Station Name             object
# dtype: object

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
import matplotlib.pyplot as plt

# %%
data
# Out:
#         Train No    Train Name  SEQ Station Code  Station Name Arrival time  \
# 0            107  SWV-MAO-VLNK    1          SWV  SAWANTWADI R     00:00:00
# 1            107  SWV-MAO-VLNK    2         THVM        THIVIM     11:06:00
# 2            107  SWV-MAO-VLNK    3         KRMI       KARMALI     11:28:00
# 3            107  SWV-MAO-VLNK    4          MAO   MADGOAN JN.     12:10:00
# 4            108  VLNK-MAO-SWV    1          MAO   MADGOAN JN.     00:00:00
# 5            108  VLNK-MAO-SWV    2         KRMI       KARMALI     21:04:00
# 6            108  VLNK-MAO-SWV    3         THVM        THIVIM     21:26:00
# 7            108  VLNK-MAO-SWV    4          SWV  SAWANTWADI R     22:25:00
# 8            128  MAO-KOP SPEC    1          MAO   MADGOAN JN.     19:40:00
# 9            128  MAO-KOP SPEC    2         KRMI       KARMALI     20:18:00
# 10           128  MAO-KOP SPEC    3         THVM        THIVIM     20:40:00
# ...

# %% [markdown]
# # Bargraph for seq and distance

# %%
plt.bar(data['SEQ'], data['Distance'])
plt.show()

# %% [markdown]
# # A box plot consist of 5 things.
#
# Minimum
# First Quartile or 25%
# Median (Second Quartile) or 50%
# Third Quartile or 75%
# Maximum

# %%
data.isna().sum()

# %%
#####del missing values by rows

# %%
data = data.dropna(axis=0, how ='any', thresh =None, subset=None, inplace = False)

# %%
data['diff_seconds'] = data['Departure Time'] - data['Arrival time']
#data['diff_seconds']=data['diff_seconds']/np.timedelta64(1,'m')
 
data.head()
# Out:
#    Train No    Train Name  SEQ Station Code  Station Name Arrival time  \
# 0       107  SWV-MAO-VLNK    1          SWV  SAWANTWADI R     00:00:00
# 1       107  SWV-MAO-VLNK    2         THVM        THIVIM     11:06:00
# 2       107  SWV-MAO-VLNK    3         KRMI       KARMALI     11:28:00
# 3       107  SWV-MAO-VLNK    4          MAO   MADGOAN JN.     12:10:00
# 4       108  VLNK-MAO-SWV    1          MAO   MADGOAN JN.     00:00:00
#
#   Departure Time  Distance Source Station Source Station Name  \
# 0       10:25:00         0            SWV     SAWANTWADI ROAD
# 1       11:08:00        32            SWV     SAWANTWADI ROAD
# 2       11:30:00        49            SWV     SAWANTWADI ROAD
# 3       00:00:00        78            SWV     SAWANTWADI ROAD
# 4       20:30:00         0            MAO         MADGOAN JN.
#
#   Destination Station Destination Station Name      diff_seconds
# 0                 MAO              MADGOAN JN.          10:25:00
# ...

# %%
data.

# %%
sns.(x="Train No", kind="box", data=tips);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-193-6c96b16f9280> in <module>()
# ----> 1 sns.categorical(x="Train No", kind="box", data=tips);
#
# NameError: name 'tips' is not defined

# %% [markdown]
# #### In the give data set every column is an object type.          Lets examine each and every coulumn.

# %% [markdown]
# ##### Column-1 Train No

# %%
data['Train No'].unique()  ### to fing no.of
# Out:
# array([  107,   108,   128, ..., 99906, 99907, 99908], dtype=int64)

# %%
s=data["Train No"].value_counts()    ##############prints only unique values
for i in data['Train No'].unique():
    print(i)
# Out:
# 107
# 108
# 128
# 290
# 401
# 421
# 422
# 477
# 502
# 504
# 506
# 557
# 604
# 1011
# 1037
# 1038
# 1045
# 1119
# 1120
# 1122
# 1196
# 1301
# 1302
# 1442
# 1655
# 1656
# 1705
# 1706
# 1707
# 1708
# 2025
# 2026
# 2191
# 2192
# 2195
# 2196
# 2515
# 2651
# 2652
# 2731
# 2732
# 2821
# 2822
# 2833
# 2834
# 2841
# 2842
# 2845
# 2846
# 3101
# 3102
# 3301
# 3302
# 3305
# 3306
# 3307
# 3308
# 3501
# 3502
# 4401
# 4402
# 4409
# 4410
# 4419
# 4420
# 4735
# 4736
# 4767
# 4768
# 4769
# 4770
# 4771
# 4772
# 4773
# 4774
# 4801
# 4802
# 4831
# 4832
# 4851
# 4852
# 4853
# 4854
# 4921
# 4922
# 4991
# 4992
# 5061
# 5062
# 5065
# 5066
# 5105
# 5106
# 5305
# 5306
# 5309
# 5310
# 5521
# 5522
# 5613
# 5614
# 5619
# 5620
# 5631
# 5632
# 5715
# 5716
# 5719
# 5720
# 5863
# 5864
# 5865
# 5866
# 6001
# 6002
# 6006
# 6009
# 6010
# 6041
# 6042
# 6043
# 6044
# 6046
# 6047
# 6048
# 6049
# 6050
# 6053
# 6054
# 6057
# 6058
# 6065
# 6066
# 6067
# 6068
# 6081
# 6082
# 6412
# 6512
# 6513
# 6541
# 6542
# 6547
# 6548
# ...

# %% [markdown]
# # bar graphs for catogorical variables

# %%
data["Train No"].value_counts().plot(kind='bar',figsize=(6,4),color="coral",fontsize=12)

# %%
data["SEQ"].value_counts().plot(kind='bar',figsize=(6,4),color="coral",fontsize=12)

# %%
data["Arrival time"].value_counts().plot(kind='bar',figsize=(6,4),color="coral",fontsize=12)

# %%
data["Arrival time"].value_counts().plot(kind='bar',figsize=(6,4),color="coral",fontsize=12)

# %%
data.dtypes
# Out:
# Train No                              int64
# Train Name                           object
# SEQ                                   int64
# Station Code                         object
# Station Name                         object
# Arrival time                timedelta64[ns]
# Departure Time              timedelta64[ns]
# Distance                              int64
# Source Station                       object
# Source Station Name                  object
# Destination Station                  object
# Destination Station Name             object
# dtype: object

# %%
[y.values]

# %%
len(data["Distance"].groupby(data["Train No"]).max().unique())
# Out:
# 1647

# %% [markdown]
# ###### There are two trains which has distance less than 3

# %%
d= data["Distance"].groupby(data["Train No"]).max()
data[data['Train No']==3306]
# Out:
#      Train No   Train Name  SEQ Station Code Station Name Arrival time  \
# 750      3306  KUSUNDA-DHN    1          KDS      KUSUNDA     12:05:00
# 751      3306  KUSUNDA-DHN    2          DHN  DHANBAD JN.     12:25:00
#
#     Departure Time  Distance Source Station Source Station Name  \
# 750       12:05:00         0            KDS             KUSUNDA
# 751       12:25:00         3            KDS             KUSUNDA
#
#     Destination Station Destination Station Name
# 750                 DHN              DHANBAD JN.
# 751                 DHN              DHANBAD JN.

# %%
data['Distance'].groupby(y).count()
# Out:
# Train No
# 2.0      1249
# 3.0       382
# 4.0       272
# 5.0       249
# 6.0       249
# 7.0       276
# 8.0       354
# 9.0       410
# 10.0      411
# 11.0      446
# 12.0      337
# 13.0      398
# 14.0      455
# 15.0      317
# 16.0      292
# 17.0      643
# 18.0      473
# 19.0      307
# 20.0      253
# 21.0      298
# 22.0      320
# 23.0      221
# 24.0      355
# 25.0      130
# 26.0      154
# 27.0      167
# 28.0      165
# 29.0      191
# 30.0      110
# 31.0      101
#          ...
# 74.0        5
# 75.0        3
# 76.0        2
# 77.0        2
# 78.0        5
# 79.0        2
# 81.0        2
# 82.0        5
# 83.0        5
# 84.0        1
# 85.0        3
# 86.0        1
# 87.0        1
# 88.0        1
# 89.0        3
# 90.0        3
# 91.0        3
# 92.0        2
# 94.0        1
# 96.0        2
# 97.0        3
# 98.0        1
# 102.0       1
# 106.0       1
# 107.0       1
# 108.0       1
# 109.0       1
# 111.0       1
# 112.0       1
# 118.0       1
# ...

# %%
plt.bar(data["Train No"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-384-98b2ece83958> in <module>()
# ----> 1 plt.bar(data["Train No"])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(*args, **kwargs)
#    2768                       mplDeprecation)
#    2769     try:
# -> 2770         ret = ax.bar(*args, **kwargs)
#    2771     finally:
#    2772         ax._hold = washold
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, *args, **kwargs)
#    2152                 break
# ...

# %%
data.info()

# %%
for i in range(x):
    dateTimeString = dt.strftime(x[i], '%I:%M:%S %p')

# %% [markdown]
# # MISSING VALUE ANALYSIS

# %%
data.isnull()
# Out:
#         Train No  Train Name    SEQ  Station Code  Station Name  Arrival time  \
# 0          False       False  False         False         False         False
# 1          False       False  False         False         False         False
# 2          False       False  False         False         False         False
# 3          False       False  False         False         False         False
# 4          False       False  False         False         False         False
# 5          False       False  False         False         False         False
# 6          False       False  False         False         False         False
# 7          False       False  False         False         False         False
# 8          False       False  False         False         False         False
# 9          False       False  False         False         False         False
# 10         False       False  False         False         False         False
# ...

# %%
data.isnull().sum()   ##### to find missing values in the data
# Out:
# Train No                    0
# Train Name                  0
# SEQ                         0
# Station Code                0
# Station Name                0
# Arrival time                0
# Departure Time              0
# Distance                    0
# Source Station              0
# Source Station Name         0
# Destination Station         0
# Destination Station Name    0
# dtype: int64

# %% [markdown]
# ###### As there are no missing values in the data set, we can proceed to the next step

# %% [markdown]
# ##### 4. There are no outliers, becoz the given data is for the train_no to diff variables. These variables are catagorical.

# %% [markdown]
# # 5. Feature engineering

# %% [markdown]
# ###### Here in the given data set we have 12 columns
# Train No
# Train Name
# SEQ
# Station Code
# Station Name
# Arrival time
# Departure TimeDistance
# Source Station
# Source Station Name
# Destination Station
# Destination Station Name

# %% [markdown]
# #### Adding another coloumn called 'time-diff' which represents the diff b/w arrival and departure time.

# %%
#### Adding another coloumn called 'time-diff' which represents the diff b/w arrival and departure time.
data['time_diff']=data['Departure Time'] - data['Arrival time']
data.head()
# Out:
#    Train No    Train Name  SEQ Station Code  Station Name Arrival time  \
# 0       107  SWV-MAO-VLNK    1          SWV  SAWANTWADI R     00:00:00
# 1       107  SWV-MAO-VLNK    2         THVM        THIVIM     11:06:00
# 2       107  SWV-MAO-VLNK    3         KRMI       KARMALI     11:28:00
# 3       107  SWV-MAO-VLNK    4          MAO   MADGOAN JN.     12:10:00
# 4       108  VLNK-MAO-SWV    1          MAO   MADGOAN JN.     00:00:00
#
#   Departure Time  Distance Source Station Source Station Name  \
# 0       10:25:00         0            SWV     SAWANTWADI ROAD
# 1       11:08:00        32            SWV     SAWANTWADI ROAD
# 2       11:30:00        49            SWV     SAWANTWADI ROAD
# 3       00:00:00        78            SWV     SAWANTWADI ROAD
# 4       20:30:00         0            MAO         MADGOAN JN.
#
#   Destination Station Destination Station Name         time_diff
# 0                 MAO              MADGOAN JN.          10:25:00
# ...

# %% [markdown]
# ##### Remove unecessary columns from the dataset.
# station name , Source Station Source Station Name, Destination Station Name
# the above mentioned columns are represents names of the satations and these names are also represented as a code name in the columns give below
# Station Code - Station Name
# Source Station - Source Station Name
# Destination Station - Destination Station Name

# %%
data.drop(columns=['Station Name', 'Source Station Name','Destination Station Name'])

# %%
s= list(data['Train No'].unique())
s[1]
# Out:
# 108

# %%
len(data['Train No'].unique())  ###### there are 11112 unique values in the Train No column
# Out:
# 11112

# %%
len(data['Source Station'].unique()) ########there are 926 unique values in the Train No column
# Out:
# 926

# %%
len(data['Destination Station Name'].unique()) ######there are 923 unique values in the Train No column
# Out:
# 923

# %%
data.head()

# %%
x = data["Arrival time"].groupby

# %%
 maxi
# Out:
# Train No
# 107     -1 days +11:50:00
# 108     -1 days +01:35:00
# 128              00:00:00
# 290              00:00:00
# 401              00:00:00
# 421              00:00:00
# 422              00:00:00
# 477              00:00:00
# 502              00:00:00
# 504              00:00:00
# 506              00:00:00
# 557              00:00:00
# 604              00:00:00
# 1011             00:00:00
# 1037             00:00:00
# 1038             00:00:00
# 1045             00:00:00
# 1119             00:00:00
# 1120             00:00:00
# 1122             00:00:00
# 1196             00:00:00
# 1301             00:00:00
# 1302             00:00:00
# 1442             00:00:00
# 1655             00:00:00
# 1656             00:00:00
# 1705             00:00:00
# 1706             00:00:00
# 1707             00:00:00
# 1708             00:00:00
#                ...
# 99815            00:00:00
# 99816            00:00:00
# 99817            00:00:00
# 99818            00:00:00
# ...

# %%
x=data["Arrival time"].groupby(data["Train No"]).sum()    ###### to get sum of Arrival time for each train

# %%
y= data["Departure time"].groupby(data["Train No"]).sum()   ###### to get sum of Departure time for each train

# %%
mini  =  data["time_diff"].groupby(data["Train No"]).min()    ######## we will get the max value for each train

# %%
maxi =  data["time_diff"].groupby(data["Train No"]).max()     #### we will get the min values for each train
